# %% [markdown]
# # Demo

# %%
import sys
# set PYTHONPATH
sys.path.append('~/Work/plot_xgt3/plot_xgt3')

# %%
# Import module
from plot_xgt3 import quick_plot
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Import module
# ----> 2 from plot_xgt3 import quick_plot
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'plot_xgt3'

# %%
data_dir='./data'
varname='T2'
levels=np.arange(240,300,5)
cmap='bwr'
year=1981
month=1
title=f'2m Temperature, {year}-{month}'
quick_plot(f'{data_dir}/{varname}', 
           levels=levels, cmap=cmap,
           year=year, month=month,
           title=title)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 data_dir='./data'
#       2 varname='T2'
# ----> 3 levels=np.arange(240,300,5)
#       4 cmap='bwr'
#       5 year=1981
#
# NameError: name 'np' is not defined

# %%
data_dir='./data'
varname='prcp'
levels=np.arange(0,0.0001,0.00001)
cmap='GnBu'
year=1981
month=1
title=f'Precipitation, {year}-{month}'
quick_plot(f'{data_dir}/{varname}', 
           levels=levels, cmap=cmap,
           year=year, month=month,
           title=title)
